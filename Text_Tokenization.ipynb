# %%
# !pip install spacy
# Out:
# ...
#      ---------------------------------------- 0.0/45.9 kB ? eta -:--:--
#      ---------------------------------------- 45.9/45.9 kB 1.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/57.6 kB ? eta -:--:--
#      ---------------------------------------- 57.6/57.6 kB 1.5 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/158.6 kB ? eta -:--:--
#      --------------- ----------------------- 61.4/158.6 kB 1.7 MB/s eta 0:00:01
#      ------------------------------------ - 153.6/158.6 kB 1.8 MB/s eta 0:00:01
#      -------------------------------------- 158.6/158.6 kB 1.4 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/181.6 kB ? eta -:--:--
#      -------------------------------------- 181.6/181.6 kB 5.4 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/61.2 kB ? eta -:--:--
#      ---------------------------------------- 61.2/61.2 kB 3.2 MB/s eta 0:00:00
# ...

# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB 1.3 MB/s eta 0:00:10
#      --------------------------------------- 0.1/12.8 MB 525.1 kB/s eta 0:00:25
#      --------------------------------------- 0.1/12.8 MB 751.6 kB/s eta 0:00:17
#      --------------------------------------- 0.1/12.8 MB 774.0 kB/s eta 0:00:17
#       -------------------------------------- 0.2/12.8 MB 831.5 kB/s eta 0:00:16
#       --------------------------------------- 0.3/12.8 MB 1.0 MB/s eta 0:00:13
#      - -------------------------------------- 0.3/12.8 MB 1.1 MB/s eta 0:00:12
#      - ------------------------------------- 0.3/12.8 MB 912.8 kB/s eta 0:00:14
#      - ------------------------------------- 0.4/12.8 MB 928.4 kB/s eta 0:00:14
#      - ------------------------------------- 0.4/12.8 MB 928.4 kB/s eta 0:00:14
#      - ------------------------------------- 0.4/12.8 MB 928.4 kB/s eta 0:00:14
# ...

# %%
nlp = spacy.load("en_core_web_sm")

# %%
doc = nlp("Hi, this is Mohamed Sadeldin. This is  demo for text tokenization and digitlization. I'm just testing spacy")

# %%
print (len(doc))
# Out:
# 22

# %%
text = doc

# %%
     for token in doc [0:22]:
        print (token)
# Out:
# Hi
# ,
# this
# is
# Mohamed
# Sadeldin
# .
# This
# is
#
# demo
# for
# text
# tokenization
# and
# digitlization
# .
# I
# 'm
# just
# testing
# spacy
